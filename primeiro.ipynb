# %% [markdown]
# <a href="https://colab.research.google.com/github/PyAutoDeni/TCC-cantina/blob/main/primeiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Olá, estou aprendendo Python!")
# Out:
# Olá, estou aprendendo Python!

# %%
idade = input("Qual seu nome?")
nome =  input("Qual sua fruta favorita?")
fruta_favorita = input("Qual sua idade?")

print (f'Sua idade é: {nome}; seu nome é: {fruta_favorita}; e sua fruta favorita é: {idade}')
# Out:
# Qual seu nome?daniel
# Qual sua fruta favorita?azul
# Qual sua idade?cor
# Sua idade é: azul; seu nome é: cor; e sua fruta favorita é: daniel

# %%
#peça ao usuario 2 números e exiba a soma e a subtração deles
num1 = int(input("Escreva um número: "))
num2 = int(input("Escreva outro número: "))
soma = num1 + num2
subtracao = num1 - num2

print (f'A soma dos números resulta em: {soma}; e a subtração resulta em: {subtracao}')
# Out:
# Escreva um número: 90
# Escreva outro número: 30
# A soma dos números resulta em: 120; e a subtração resulta em: 60
